# %% [markdown]
# <a href="https://colab.research.google.com/github/SRezaA102/MachineLearningTask/blob/main/Minggu5/5_EDA_IT_Salary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TUGAS 5
# *   NAMA = Syahrul Reza Ananda
# *   NIM = 1103210113
# *   Model = EDA
# *   Dataset = IT Salary Survey EU  2020.csv

# %% [markdown]
# Penjelasan Fitur-fitur
# Timestamp

# %% [markdown]
# # **Promp Chat-GPT**

# %% [markdown]
# 1. Beri kode untuk read dataset as dataframe dengan path "/content/drive/MyDrive/Machine Learning/Minggu 5/IT Salary Survey EU  2020.csv"
# 2. Beri kode untuk menampilkan informasi ringkas dari dataframe!
# 3. Beri petunjuk untuk melakukan Exploratory Data Analysis!
# 4. Beri Kode untuk mendapatkan Summary statistic dari DataFrame
# 5. Beri kode untuk melihat 5 baris teratas dari fitur-fitur tertentu berikut: "Total years of experience", "Years of experience in Germany", "Yearly bonus + stocks in EUR", "Annual bonus+stocks one year ago. Only answer if staying in same country", "Number of vacation days", "Сontract duration", "Company size"
# 6. Beri kode untuk mengubah fitur-fitur tertentu berikut: "Total years of experience", "Years of experience in Germany", "Yearly bonus + stocks in EUR", "Annual bonus+stocks one year ago. Only answer if staying in same country", "Number of vacation days", bertipe data numerik!
# 7. ChatGPT Prompt: Beri kode untuk memperbarui nama-nama fitur berikut:
# *   Total years of experience -> Total experience
# *   Years of experience in Germany -> Experience in Germany
# *   Your main technology / programming language -> Main programming language
# *   Other technologies/programming languages you use often -> Other programming languages
# *   Yearly brutto salary (without bonus and stocks) in EUR -> Yearly brutto salary
# *   Yearly bonus + stocks in EUR -> Yearly bonus and stocks
# *   Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country -> Previous yearly brutto salary
# *   Annual bonus+stocks one year ago. Only answer if staying in same country -> Previous yearly bonus and stocks
# *   Number of vacation days -> Vacation days
# *   Main language at work -> Main work language
# *   Have you lost your job due to the coronavirus outbreak? -> Lost job due to COVID-19
# *   Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week -> Kurzarbeit hours per week
# *   Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR -> Additional monetary support in 2020
#
# 8. Beri baris untuk menampilkan baris yang memiliki null value
# 9. Beri kode untuk mengisi baris dari fitur "Kurzarbeit hours per week" yang memiliki null value dengan nilai "0"
# 10. Beri kode untuk menampilkan pie diagram chart untk fitur Age dengan min 20, max 69
# 11. Beri kode untuk menampilkan baris data yang memiliki Age '51-60', '60+'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %%
url = "/content/drive/MyDrive/Machine Learning/Minggu 5/IT Salary Survey EU  2020.csv"

# Membaca file CSV dan membuat DataFrame
df = pd.read_csv(url)

# %% [markdown]
# # **Memuat Data**

# %%
# Menampilkan beberapa baris pertama dari DataFrame
df.head()
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# ...

# %%
df.tail()
# Out:
#                 Timestamp   Age Gender         City  \
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01:11  26.0   Male       Berlin
#
#                                    Position  Total years of experience  \
# 1248                       Backend Developer                         9
# 1249  Researcher/ Consumer Insights Analyst                         10
# 1250                   IT Operations Manager                        15
# 1251                      Frontend Developer                         7
# 1252                                  DevOps                         2
#
#      Years of experience in Germany Seniority level  \
# 1248                              5          Senior
# 1249                            1.5          Senior
# 1250                              2            Lead
# ...

# %% [markdown]
# # **Mengeksplor Data**

# %%
#Menampilkan ringkasan tentang DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                1253 non-null   object
#  1   Age                                                                                                                      1226 non-null   float64
#  2   Gender                                                                                                                   1243 non-null   object
# ...

# %%
#Menampilkan Summary statistic dari DataFrame
df.describe()
# Out:
#                Age  Yearly brutto salary (without bonus and stocks) in EUR  \
# count  1226.000000                                       1.253000e+03
# mean     32.509788                                       8.027904e+07
# std       5.663804                                       2.825061e+09
# min      20.000000                                       1.000100e+04
# 25%      29.000000                                       5.880000e+04
# 50%      32.000000                                       7.000000e+04
# 75%      35.000000                                       8.000000e+04
# max      69.000000                                       1.000000e+11
#
#        Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country  \
# count                                       8.850000e+02
# mean                                        6.322459e+05
# std                                         1.680508e+07
# ...

# %%
# Memilih fitur-fitur yang ingin ditampilkan
selected_features = [
    "Total years of experience",
    "Years of experience in Germany",
    "Yearly bonus + stocks in EUR",
    "Annual bonus+stocks one year ago. Only answer if staying in same country",
    "Number of vacation days",
    "Сontract duration",
    "Company size"
]
# Menampilkan 5 baris teratas dari fitur-fitur yang dipilih
df[selected_features].head()
# Out:
#   Total years of experience Years of experience in Germany  \
# 0                         5                              3
# 1                         7                              4
# 2                        12                              6
# 3                         4                              1
# 4                        17                              6
#
#   Yearly bonus + stocks in EUR  \
# 0                         5000
# 1                          NaN
# 2                       120000
# 3                          NaN
# 4                          NaN
#
#   Annual bonus+stocks one year ago. Only answer if staying in same country  \
# 0                                              10000
# 1                                               5000
# 2                                             100000
# 3                                                NaN
# 4                                                NaN
#
#   Number of vacation days   Сontract duration Company size
# ...

# %% [markdown]
# # **Merapihkan Data**

# %%
# Memilih fitur-fitur yang ingin diubah tipe datanya
selected_features = [
    "Total years of experience",
    "Years of experience in Germany",
    "Yearly bonus + stocks in EUR",
    "Annual bonus+stocks one year ago. Only answer if staying in same country",
    "Number of vacation days"
]

# Mengubah tipe data fitur-fitur yang dipilih menjadi numerik
df[selected_features] = df[selected_features].apply(pd.to_numeric, errors='coerce')

# Menampilkan tipe data setelah perubahan
df[selected_features].dtypes
# Out:
# Total years of experience                                                   float64
# Years of experience in Germany                                              float64
# Yearly bonus + stocks in EUR                                                float64
# Annual bonus+stocks one year ago. Only answer if staying in same country    float64
# Number of vacation days                                                     float64
# dtype: object

# %%
# Membuat kamus untuk memetakan nama fitur yang lama ke nama fitur yang baru
feature_mapping = {
    "Total years of experience": "Total experience",
    "Years of experience in Germany": "Experience in Germany",
    "Your main technology / programming language": "Main programming language",
    "Other technologies/programming languages you use often": "Other programming languages",
    "Yearly brutto salary (without bonus and stocks) in EUR": "Yearly brutto salary",
    "Yearly bonus + stocks in EUR": "Yearly bonus and stocks",
    "Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country": "Previous yearly brutto salary",
    "Annual bonus+stocks one year ago. Only answer if staying in same country": "Previous yearly bonus and stocks",
    "Number of vacation days": "Vacation days",
    "Main language at work": "Main work language",
    "Have you lost your job due to the coronavirus outbreak?": "Lost job due to COVID-19",
    "Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week": "Kurzarbeit hours per week",
    "Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR": "Additional monetary support in 2020"
}

# Memperbarui nama-nama fitur dalam dataframe
df = df.rename(columns=feature_mapping)

# Menampilkan nama-nama fitur setelah diperbarui
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'City', 'Position ', 'Total experience',
#        'Experience in Germany', 'Seniority level', 'Main programming language',
#        'Other programming languages', 'Yearly brutto salary',
#        'Yearly bonus and stocks', 'Previous yearly brutto salary',
#        'Previous yearly bonus and stocks', 'Vacation days',
#        'Employment status', 'Сontract duration', 'Main work language',
#        'Company size', 'Company type', 'Lost job due to COVID-19',
#        'Kurzarbeit hours per week', 'Additional monetary support in 2020'],
#       dtype='object')

# %%
# Mengidentifikasi baris yang memiliki nilai null
rows_with_null = df[df.isnull().any(axis=1)]

# Menampilkan baris yang memiliki nilai null
rows_with_null
# Out:
#                 Timestamp   Age Gender         City  \
# 0     24/11/2020 11:14:15  26.0   Male       Munich
# 1     24/11/2020 11:14:16  26.0   Male       Berlin
# 2     24/11/2020 11:14:21  29.0   Male       Berlin
# 3     24/11/2020 11:15:24  28.0   Male       Berlin
# 4     24/11/2020 11:15:46  37.0   Male       Berlin
# ...                   ...   ...    ...          ...
# 1247  18/01/2021 11:50:02  34.0   Male       Zurich
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
#
#                                    Position   Total experience  \
# 0                          Software Engineer               5.0
# 1                          Backend Developer               7.0
# 2                          Software Engineer              12.0
# 3                         Frontend Developer               4.0
# ...

# %%
# Mengisi nilai null dalam kolom "Kurzarbeit hours per week" dengan nilai "0"
df["Kurzarbeit hours per week"].fillna(0, inplace=True)

# Menampilkan baris yang memiliki nilai null setelah pengisian
df[df["Kurzarbeit hours per week"].isnull()]

# Cek apakah ada nilai null di kolom "Kurzarbeit hours per week"
df["Kurzarbeit hours per week"].isnull().sum()

# Gunakan metode info() untuk melihat informasi tentang dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Timestamp                            1253 non-null   object
#  1   Age                                  1226 non-null   float64
#  2   Gender                               1243 non-null   object
#  3   City                                 1253 non-null   object
#  4   Position                             1247 non-null   object
#  5   Total experience                     1230 non-null   float64
#  6   Experience in Germany                1194 non-null   float64
#  7   Seniority level                      1241 non-null   object
#  8   Main programming language            1126 non-null   object
#  9   Other programming languages          1096 non-null   object
#  10  Yearly brutto salary                 1253 non-null   float64
# ...

# %% [markdown]
# # **Visualisasi Data**

# %%
# Filter data sesuai rentang usia yang ditentukan (20 hingga 69 tahun)
filtered_df = df[(df['Age'] >= 20) & (df['Age'] <= 69)]

# Menghitung jumlah individu dalam setiap kelompok usia
age_counts = filtered_df['Age'].value_counts()

# Membuat diagram pie
plt.figure(figsize=(8, 8))
plt.pie(age_counts, labels=age_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart of Age Distribution (Ages 20 to 69)')
plt.axis('equal')  # Memastikan lingkaran terlihat seperti lingkaran
plt.show()

# %%
# Memilih baris data yang memiliki usia antara 51 dan 60 atau di atas 60
selected_rows = df.loc[(df['Age'] >= 51) & (df['Age'] <= 60) | (df['Age'] > 60)]

# Menampilkan baris data yang dipilih
selected_rows
# Out:
#                 Timestamp   Age Gender        City           Position   \
# 23    24/11/2020 11:23:11  59.0   Male      Berlin   Backend Developer
# 59    24/11/2020 11:33:51  66.0   Male      Munich   Software Engineer
# 232   24/11/2020 13:53:01  56.0   Male  Ingolstadt   Software Engineer
# 233   24/11/2020 13:54:47  53.0   Male   Stuttgart  Frontend Developer
# 296   24/11/2020 15:39:13  65.0   Male      Berlin   Software Engineer
# 673   25/11/2020 18:56:02  51.0   Male      Berlin   Software Engineer
# 955   30/11/2020 12:56:08  54.0   Male      Milano              Sales
# 1103  06/12/2020 21:51:21  69.0   Male   Stuttgart             Rentner
# 1159  14/12/2020 08:55:24  56.0   Male      Munich   Software Engineer
# 1182  20/12/2020 01:48:34  54.0   Male      Munich   Software Engineer
# 1232  08/01/2021 16:12:36  52.0   Male   Stuttgart   Software Engineer
#
#       Total experience  Experience in Germany Seniority level  \
# ...
